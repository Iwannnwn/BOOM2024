# %% [markdown]
# # <b>INTRODUCTION TO SQL USING PYTHON FOR DATA ANALYSIS</b>

# %%
# import library sqlite3
import sqlite3

# %%
# Membuat atau menghubungkan ke database
com = sqlite3.connect('C:/Users/Asus/OneDrive - Institut Teknologi Sepuluh Nopember/Desktop/DOCS/BOOM 2024/Data/database.sqlite')

# Membuat objek cursor untuk menjalankan perintah sql
cursor = com.cursor()

# %% [markdown]
# ## <b> MEMBACA LIST TABLE DI DALAM DATABASE </b>

# %%
# Menjalankan perintah untuk mendapatkan nama daftar tabel
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# %%
# Menyimpan dan menampilkan hasil
tables = cursor.fetchall()
print("Tables in database:")
for table in tables:
    print(table[0])
# Out:
# Tables in database:
# sqlite_sequence
# Player_Attributes
# Player
# Match
# League
# Country
# Team
# Team_Attributes

# %%
# Menentukan nama tabel yang akan diakses
table_name = 'Player' # Nama tabel yang akan diakses

# Menjalankan perintah untuk mendapatkan nama kolom
cursor.execute(f"PRAGMA table_info({table_name})")

# Menyimpan dan menampilkan hasil
columns = cursor.fetchall()
print(f"Columns in table'{table_name}':")
for column in columns:
    print(column[1])
# Out:
# Columns in table'Player':
# id
# player_api_id
# player_name
# player_fifa_api_id
# birthday
# height
# weight

# %%
# Membaca data dari tabel
cursor.execute('SELECT * FROM Player LIMIT 10')
all_player = cursor.fetchall()
all_player
# Out:
# [(1, 505942, 'Aaron Appindangoye', 218353, '1992-02-29 00:00:00', 182.88, 187),
#  (2, 155782, 'Aaron Cresswell', 189615, '1989-12-15 00:00:00', 170.18, 146),
#  (3, 162549, 'Aaron Doran', 186170, '1991-05-13 00:00:00', 170.18, 163),
#  (4, 30572, 'Aaron Galindo', 140161, '1982-05-08 00:00:00', 182.88, 198),
#  (5, 23780, 'Aaron Hughes', 17725, '1979-11-08 00:00:00', 182.88, 154),
#  (6, 27316, 'Aaron Hunt', 158138, '1986-09-04 00:00:00', 182.88, 161),
#  (7, 564793, 'Aaron Kuhl', 221280, '1996-01-30 00:00:00', 172.72, 146),
#  (8, 30895, 'Aaron Lennon', 152747, '1987-04-16 00:00:00', 165.1, 139),
#  (9, 528212, 'Aaron Lennox', 206592, '1993-02-19 00:00:00', 190.5, 181),
#  (10, 101042, 'Aaron Meijers', 188621, '1987-10-28 00:00:00', 175.26, 170)]

# %% [markdown]
# # <b> MENGKONEKSIKAN PANDAS DENGAN SQLITE3 </b>

# %%
# import library pandas
import pandas as pd #type: ignore

# %%
data = pd.read_sql_query('SELECT * FROM Player', com)
data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11060 entries, 0 to 11059
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  11060 non-null  int64
#  1   player_api_id       11060 non-null  int64
#  2   player_name         11060 non-null  object
#  3   player_fifa_api_id  11060 non-null  int64
#  4   birthday            11060 non-null  object
#  5   height              11060 non-null  float64
#  6   weight              11060 non-null  int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 605.0+ KB

# %% [markdown]
# # <b> FILTER DATA </b>

# %%
# Melakukan filter untuk pemain dengan tinggi >= 180
data = pd.read_sql_query('''SELECT *
                            FROM Player
                            WHERE height >= 180
                            ''', com)
data
# Out:
#          id  player_api_id          player_name  player_fifa_api_id  \
# 0         1         505942   Aaron Appindangoye              218353
# 1         4          30572        Aaron Galindo              140161
# 2         5          23780         Aaron Hughes               17725
# 3         6          27316           Aaron Hunt              158138
# 4         9         528212         Aaron Lennox              206592
# ...     ...            ...                  ...                 ...
# 7253  11071          26357       Zoumana Camara                2488
# 7254  11072         111182         Zsolt Laczko              164680
# 7255  11073          36491            Zsolt Low              111191
# 7256  11074          35506  Zurab Khizanishvili               47058
# 7257  11075          39902   Zvjezdan Misimovic              102359
#
#                  birthday  height  weight
# 0     1992-02-29 00:00:00  182.88     187
# 1     1982-05-08 00:00:00  182.88     198
# ...

# %%
# Melakukan filter untuk pemain dengan berat >= 170
data = pd.read_sql_query('''SELECT *
                            FROM Player
                            WHERE weight >= 170
                            ''', com)
data
# Out:
#          id  player_api_id          player_name  player_fifa_api_id  \
# 0         1         505942   Aaron Appindangoye              218353
# 1         4          30572        Aaron Galindo              140161
# 2         9         528212         Aaron Lennox              206592
# 3        10         101042        Aaron Meijers              188621
# 4        11          23889        Aaron Mokoena               47189
# ...     ...            ...                  ...                 ...
# 5252  11067          56929       Zoran Rendulic              188593
# 5253  11070         282473       Zouhair Feddal              205705
# 5254  11072         111182         Zsolt Laczko              164680
# 5255  11074          35506  Zurab Khizanishvili               47058
# 5256  11075          39902   Zvjezdan Misimovic              102359
#
#                  birthday  height  weight
# 0     1992-02-29 00:00:00  182.88     187
# 1     1982-05-08 00:00:00  182.88     198
# ...

# %% [markdown]
# # <b> OPERATOR RASIONAL DAN LOGIKA </b>
# Operator rasional dan logika digunakan untuk membandingkan nilai dan menggabungkan kondisi logika. Berikut adalah beberapa contoh operator rasional dan logika yang umum digunakan:
#
# ### <b>Operator Rasional</b>
# - `==` : Sama dengan
# - `!=` : Tidak sama dengan
# - `>` : Lebih besar dari
# - `<` : Lebih kecil dari
# - `>=` : Lebih besar atau sama dengan
# - `<=` : Lebih kecil atau sama dengan
#
# ### <b>Operator Logika</b>
# - `and` : Mengembalikan True jika kedua kondisi adalah True
# - `or` : Mengembalikan True jika salah satu kondisi adalah True
# - `not` : Membalikkan nilai boolean
#
# ### <b>Operator LIKE</b>
# - `LIKE` : Digunakan untuk mencocokkan pola dalam teks
#
# ### <b>Operator BETWEEN</b>
# - `BETWEEN` : Digunakan untuk memilih nilai dalam rentang tertentu

# %%
# Mecari nama pemain yang mengandung kata Hunt
data = pd.read_sql_query('''SELECT *
                            FROM Player
                            WHERE player_name LIKE "% Hunt%"
                            ''', com)
data
# Out:
#      id  player_api_id          player_name  player_fifa_api_id  \
# 0     6          27316           Aaron Hunt              158138
# 1  5853          36784  Klaas Jan Huntelaar              148803
# 2  8042          33692            Noel Hunt               16177
# 3  9984          23225         Stephen Hunt              160311
#
#               birthday  height  weight
# 0  1986-09-04 00:00:00  182.88     161
# 1  1983-08-12 00:00:00  185.42     183
# 2  1982-12-26 00:00:00  172.72     163
# 3  1981-08-01 00:00:00  172.72     159

# %% [markdown]
# # <b>PENGURUTAN DATA (ORDER BY)</b>

# %%
# Pengurutan data pemain yang mengandung kata hunt berdasarkan alfabet
data = pd.read_sql_query(''' SELECT *
                             FROM Player
                             WHERE player_name LIKE "% Hunt%"
                             ORDER BY player_name DESC
                             ''', com)
data
# Out:
#      id  player_api_id          player_name  player_fifa_api_id  \
# 0  9984          23225         Stephen Hunt              160311
# 1  8042          33692            Noel Hunt               16177
# 2  5853          36784  Klaas Jan Huntelaar              148803
# 3     6          27316           Aaron Hunt              158138
#
#               birthday  height  weight
# 0  1981-08-01 00:00:00  172.72     159
# 1  1982-12-26 00:00:00  172.72     163
# 2  1983-08-12 00:00:00  185.42     183
# 3  1986-09-04 00:00:00  182.88     161

# %% [markdown]
# # <b> AGREGASI </b>

# %%
# Mendapatkan tinggi minimum dari pemain
data = pd.read_sql_query(''' SELECT MIN(height) AS tinggi_minimum
                                FROM Player
                                ''', com)
data
# Out:
#    tinggi_minimum
# 0          157.48

# %% [markdown]
# # <b>GROUP BY</b>

# %%
# Mencari tinggi badan dengan total pemain  > 500
data = pd.read_sql_query(''' SELECT height, COUNT(*) AS total_pemain
                             FROM Player
                             GROUP BY 1
                             HAVING total_pemain > 500
                             ''', com)
data
# Out:
#    height  total_pemain
# 0  172.72           530
# 1  175.26          1188
# 2  177.80          1489
# 3  180.34          1388
# 4  182.88          1954
# 5  185.42          1278
# 6  187.96          1305
# 7  190.50           652

# %%
# HAVING untuk filter data setelah GROUP BY
data = pd.read_sql_query(''' SELECT height, COUNT(height) AS total_pemain
                                FROM Player
                                GROUP BY 1
                                HAVING total_pemain > 1000
                                ORDER BY 2 DESC
                                ''', com)
data
# Out:
#    height  total_pemain
# 0  182.88          1954
# 1  177.80          1489
# 2  180.34          1388
# 3  187.96          1305
# 4  185.42          1278
# 5  175.26          1188

# %% [markdown]
# # <b>UNION</b>
# UNION dalam SQL adalah operator yang digunakan untuk menggabungkan hasil dari dua atau lebih pernyataan SELECT menjadi satu hasil gabungan. Setiap pernyataan SELECT dalam UNION harus memiliki jumlah kolom yang sama dalam hasilnya dengan tipe data yang kompatibel. Hasil dari UNION hanya akan menampilkan baris yang unik (tidak ada duplikasi).
#
# <b>Contoh penggunaan:</b>
#
# SELECT kolom1, kolom2 FROM tabel1 <br>
# UNION <br>
# SELECT kolom1, kolom2 FROM tabel2;
#
# <b>Catatan:</b>
# - Untuk menyertakan baris duplikat, gunakan UNION ALL.
# - Kolom yang digabungkan harus memiliki tipe data yang sama atau kompatibel.

# %%
sql = '''SELECT *, 0 AS is_under
         FROM Player
         Where height >= (SELECT AVG(height) FROM Player)
         UNION ALL
         SeLECT *, 1 AS is_under
         FROM Player
         WHERE height < (SELECT AVG(height) FROM Player)
         '''

data = pd.read_sql_query(sql, com)
data
# Out:
#           id  player_api_id         player_name  player_fifa_api_id  \
# 0          1         505942  Aaron Appindangoye              218353
# 1          4          30572       Aaron Galindo              140161
# 2          5          23780        Aaron Hughes               17725
# 3          6          27316          Aaron Hunt              158138
# 4          9         528212        Aaron Lennox              206592
# ...      ...            ...                 ...                 ...
# 11055  11064         107281      Zoltan Stieber              179712
# 11056  11068          99031         Zoran Tosic              105454
# 11057  11069         192132  Zouhaier Dhaouadhi              195840
# 11058  11073          36491           Zsolt Low              111191
# 11059  11075          39902  Zvjezdan Misimovic              102359
#
#                   birthday  height  weight  is_under
# 0      1992-02-29 00:00:00  182.88     187         0
# ...

# %% [markdown]
# # <b>LATIHAN</b>
